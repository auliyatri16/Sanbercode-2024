# %% [markdown]
# # Soal 1: Pemahaman Teori
# Jelaskan perbedaan antara Univariate, Bivariate dan Multivariate Analysis

# %% [markdown]
# Jawaban:

# %% [markdown]
# Analisis univariate yaitu analisis yang merangkum satu variabel salam satu waktu. Kemudian, analisis bivariate yaitu analisis yang membandingkan dua variabel. Terakhir, analisis multivariate yaitu analisis yang membandingkan lebih dari sua variabel.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 2. Persiapan Data
#
# *   Hapus nilai missing dalam rows dataset menggunakan atribut.dropna()
#
# *   Lakukan grouping data berdasarkan kolom 'species' dengan menggunakan agregasi mean()

# %%
#code here
df.dropna()
df1=df.groupby('species').agg({'bill_length_mm':'mean', 'bill_depth_mm':'mean',
                           'flipper_length_mm': 'mean', 'body_mass_g':'mean'})

# %% [markdown]
# Expected output:
#
# ![tanpa handling missing value](https://drive.google.com/uc?id=1OnuXmscVRqduqT_TYI1vB291rpXM4D_1)

# %% [markdown]
# # Soal 3. Univariate Analysis
# Buatlah sebuah analisa univariate dengan menggunakan perintah seperti berikut:
#
# *   Buatlah sebuah Pie plot dari dataset hasil grouping untuk kolom flipper_length_mm seperti expected output berikut:
# *   Buatlah sebuah plot histogram dari dataset awal (sebelum grouping) untuk kolom body_mass_g
# *   Jelaskan insight yang diperoleh dari ke dua grafik tersebut.

# %%
#code here
df1.plot(kind='pie', y='flipper_length_mm',
         autopct='%1.0f%%', legend=False, ylabel=' ')
# Out:
# <Axes: ylabel=' '>

# %%
df.plot(kind='hist', column='body_mass_g', xlabel='body_mass_g', ylabel='count',
       legend=False)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='count'>

# %% [markdown]
# Expected Output:
#
#
# Pie Chart
#
# ![](https://drive.google.com/uc?id=11H6X7xpEeodPWD56tHBhV4sLrJ-6B-Bd)
#
# Histogram
#
# ![](https://drive.google.com/uc?id=1A_twS7BbQhkGvUz7zAWgye7q3ZRTQkhi)

# %% [markdown]
# Analisa: 3.a. Berdasarkan hasil grafik pie yang didapatkan nilai rata-rata panjang flipper (tangan/sayap pingiun) terbesar terdapat pada species Gentoo yaitu 36%. Sedangkan, untuk species adelie dan chinstrap memiliki nilai rata-rata panjang flipper (tangan/sayap pingiun) yaitu 32%.
# b. Berdasarkan grafik histogram nilai body mass atau berat badan pingiun didapatkan sekitar 70 pingiun dengan berat sekitar 3500-3750 g (jumlah terbanyak). Kemudian didapatkan sekitar 5 pingiun dengan berat sekitar 5800-6500 gram (jumlah tersedikit)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 4. Bivariate Analysis
#
#
#
# *   Buatlah sebuah grafik catplot menggunakan seaborn dengan x='sex', y='bill_length_mm' dan kind 'bar' seperti expected output di bawah
# *   Buatlah sebuah grafik scatter plot menggunakan seaborn dengan x='body_mass_g', y='flipper_length_mm', hue='bill_length_mm' seperti expected dibawah
# *   Jelaskan insight yang diperoleh dari hasil analisa bivariate tersebut

# %%
#code here
sns.catplot(df, x='sex', y='bill_length_mm', hue='sex', kind='bar', legend=False)

# %%
sns.scatterplot (df, x='body_mass_g', y='flipper_length_mm', hue='bill_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# Expected Output:
#
# Catplot
#
# ![](https://drive.google.com/uc?id=1imCbGD9cWqXUjd33tAh6D0OH20vVpWea)
#
# Scatter plot
#
# ![](https://drive.google.com/uc?id=1_k734IpRYq6Q1wF57hwzSEjnVd2Sii2Z)

# %% [markdown]
# Analisa: 3a. Berdasarkan grafik catplot, didapatkan pada jenis kelamin (sex) jantan penguin, memiliki panjang paruh (bill) yang lebih tinggi dibandingkan dengan betina. Nilai paruh jantan didapatkan sekitar 47 mm , sedangkan nilai paruh betina didapatkan sekitar 43 mm.
# b. Berdasarkan grafik scatterplot, dapat dilihat bahwa persebaran nilai massa (body mass), sayap (flipper), dan paruh (bill) saling mempengaruhi satu sama lain. Semakin muda warna scatterplot maka datanya semakin bawah-kiri atau dapat disimpulkan bahwa semakin kecil berat massa penguin, maka semakin kecil juga panjang paruh dan sayapnya. Begitu juga sebaliknya semakin tua warna scatterplot maka datanya semakin atas-kanan atau dapat disimpulkan bahwa semakin besar berat massa penguin, maka semakin besar juga panjang paruh dan sayapnya.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 5. Multivariate Analisis
#
# *   Dengan menggunakan seaborn, buatlah sebuah pairplot keseluruhan data feature pada dataset (df) dengan argumen kind='bar', seperti expected di bawah:
# *   Jelaskan hasil analisa dari multivariate yang dihasilkan

# %%
#code here
sns.pairplot(df, kind='scatter')

# %% [markdown]
# Expected output:
#
# Pair plot
#
# ![](https://drive.google.com/uc?id=1td8WAZLJEW5BPTq-wEJyZ4soRNNLXfqX)

# %% [markdown]
# Analisa: Berdasarkan data grafik pairplot tersebut didapatkan bahwa analisis yang digunakan yaitu multivariate karena terdiri dari banyak variabel yang saling terkait.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
